# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
import os

# %%
file_path = "/Users/ryanreid/Documents/Machine Learning/fifa/archive/players_22.csv"

fifa_df = pd.read_csv(file_path)
# Out:
# /var/folders/z6/hgtgdd9502lbqgzmmg88__ym0000gn/T/ipykernel_20863/248109373.py:3: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   fifa_df = pd.read_csv(file_path)

# %%
fifa_df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
fifa_df.describe()
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   19239.000000  19239.000000  19239.000000  1.916500e+04   19178.000000
# mean   231468.086959     65.772182     71.079370  2.850452e+06    9017.989363
# std     27039.717497      6.880232      6.086213  7.613700e+06   19470.176724
# min        41.000000     47.000000     49.000000  9.000000e+03     500.000000
# 25%    214413.500000     61.000000     67.000000  4.750000e+05    1000.000000
# 50%    236543.000000     66.000000     71.000000  9.750000e+05    3000.000000
# 75%    253532.500000     70.000000     75.000000  2.000000e+06    8000.000000
# max    264640.000000     93.000000     95.000000  1.940000e+08  350000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  19239.000000  19239.000000  19239.000000   19178.000000  19178.000000
# mean      25.210822    181.299704     74.943032   50580.498123      1.354364
# ...

# %%
fifa_df.shape
# Out:
# (19239, 110)

# %%
fifa_df.dtypes
# Out:
# sofifa_id            int64
# player_url          object
# short_name          object
# long_name           object
# player_positions    object
#                      ...
# player_face_url     object
# club_logo_url       object
# club_flag_url       object
# nation_logo_url     object
# nation_flag_url     object
# Length: 110, dtype: object

# %%
fifa_df.count()
# Out:
# sofifa_id           19239
# player_url          19239
# short_name          19239
# long_name           19239
# player_positions    19239
#                     ...
# player_face_url     19239
# club_logo_url       19178
# club_flag_url       19178
# nation_logo_url       759
# nation_flag_url     19239
# Length: 110, dtype: int64

# %%
n = len(pd.unique(fifa_df['sofifa_id']))
print("number of unique vales: ", n)
# Out:
# number of unique vales:  19239

# %%
missing_data = fifa_df.isnull().sum()


print(missing_data[missing_data > 0])
# Out:
# value_eur                       74
# wage_eur                        61
# club_team_id                    61
# club_name                       61
# league_name                     61
# league_level                    61
# club_position                   61
# club_jersey_number              61
# club_loaned_from             18137
# club_joined                   1163
# club_contract_valid_until       61
# nation_team_id               18480
# nation_position              18480
# nation_jersey_number         18480
# release_clause_eur            1176
# player_tags                  17798
# player_traits                 9841
# pace                          2132
# shooting                      2132
# passing                       2132
# dribbling                     2132
# defending                     2132
# physic                        2132
# goalkeeping_speed            17107
# club_logo_url                   61
# club_flag_url                   61
# nation_logo_url              18480
# ...

# %%
fifa_df["overall"].plot()
# Out:
# <AxesSubplot:>

# %%
fifa_df["nationality_name"].sum()
# Out:
# "ArgentinaPolandPortugalBrazilBelgiumSloveniaFranceGermanyGermanyEnglandFranceFranceBelgiumKorea RepublicBrazilNetherlandsSenegalEgyptBrazilGermanyBrazilItalySpainUruguayGermanyBelgiumCosta ...ôte d'IvoireFranceGermanyEnglandBrazilMexicoBelgiumSpainDenmarkBosnia and ... and HerzegovinaSpainGermanyBrazilGermanyBrazilDenmarkNetherlandsGermanyFranceMexicoFranceSenegalRussiaGermanyBrazilSpainCôte d'IvoireColombiaPortugalSpainBrazilFranceSpainBelgiumSpainSpainTurkeyGermanySpainNetherlandsMoroccoSpainItalyItalyArgentinaItalyGermanyBrazilBrazilArgentinaPortugalBrazilCroatiaFranceEnglandItalyNorwayPortugalPortugalEnglandSpainUnited StatesPortugalFranceSpainJamaicaEnglandBrazilBrazilSpainBrazilArgentinaNetherlandsBrazilSwedenEnglandCanadaGermanyMoroccoFranceCzech RepublicBrazilSpainSpainCroatiaSpainSpainTurkeyPortugalFranceMexicoItalyFranceArgentinaPortugalBelgiumBrazilSpainCroatiaChileGermanyAustriaUkraineFranceArgentinaDenmarkSpainAlgeriaSloveniaEnglandPortugalSpainColombiaBrazilSpainNether
# ...

# %%
# Get counts of nationality:

fifa_df["nationality_name"].value_counts()
# Out:
# England             1719
# Germany             1214
# Spain               1086
# France               980
# Argentina            960
#                     ...
# Ethiopia               1
# Papua New Guinea       1
# Kyrgyzstan             1
# Guam                   1
# Indonesia              1
# Name: nationality_name, Length: 163, dtype: int64

# %%
# How many Scottish players!?

series = fifa_df["nationality_name"].value_counts()

for index, value in series.items():
    if index == "Scotland":
        print(f"Index : {index}, Value : {value}")
# Out:
# Index : Scotland, Value : 293

# %%
# Distribution of overall rating

plt.hist(fifa_df["overall"], bins=100, rwidth=0.9)
# Out:
# (array([1.900e+01, 0.000e+00, 4.500e+01, 0.000e+00, 7.500e+01, 0.000e+00,
#         9.700e+01, 0.000e+00, 1.360e+02, 0.000e+00, 2.090e+02, 0.000e+00,
#         0.000e+00, 2.320e+02, 0.000e+00, 2.930e+02, 0.000e+00, 3.360e+02,
#         0.000e+00, 3.620e+02, 0.000e+00, 4.390e+02, 0.000e+00, 4.910e+02,
#         0.000e+00, 0.000e+00, 5.530e+02, 0.000e+00, 7.830e+02, 0.000e+00,
#         7.750e+02, 0.000e+00, 1.023e+03, 0.000e+00, 1.127e+03, 0.000e+00,
#         1.188e+03, 0.000e+00, 0.000e+00, 1.251e+03, 0.000e+00, 1.137e+03,
#         0.000e+00, 1.195e+03, 0.000e+00, 1.069e+03, 0.000e+00, 9.390e+02,
#         0.000e+00, 0.000e+00, 8.720e+02, 0.000e+00, 7.660e+02, 0.000e+00,
#         7.330e+02, 0.000e+00, 6.650e+02, 0.000e+00, 4.620e+02, 0.000e+00,
#         5.030e+02, 0.000e+00, 0.000e+00, 3.280e+02, 0.000e+00, 2.730e+02,
#         0.000e+00, 2.000e+02, 0.000e+00, 1.540e+02, 0.000e+00, 1.210e+02,
#         0.000e+00, 1.040e+02, 0.000e+00, 0.000e+00, 8.500e+01, 0.000e+00,
# ...

# %%
#creating sample data - wages v overall
fifa_df.plot(x='overall', y='wage_eur', style='o')
# Out:
# <AxesSubplot:xlabel='overall'>

# %%
# overall quality in each league

fifa_df.boxplot(column=['overall'], by='league_name', figsize=(10, 8))
plt.xticks(rotation=90)
plt.tight_layout()

# %%
# Let's plot the relationship between player height and potential


# fig, ax = plt.subplots(figsize = (8,5))
# ax = sns.scatterplot(x =df['height_cm'], y = df['potential'])
# plt.xlabel("Height") 
# plt.ylabel("Potential")
# plt.title("Relationship between Height and Potential", fontsize = 16)
# plt.show()

# %%
top_15 = fifa_df.nlargest(15, 'overall')
top_15.head(5)

fig, ax = plt.subplots(figsize=(8,5))

plt.scatter(top_15['overall'], top_15['mentality_composure'])

plt.text(top_15.iloc[0]['overall'], top_15.iloc[0]['mentality_composure'], top_15.iloc[0]['short_name'])
plt.text(top_15.iloc[1]['overall'], top_15.iloc[1]['mentality_composure'], top_15.iloc[1]['short_name'])
plt.text(top_15.iloc[2]['overall'], top_15.iloc[2]['mentality_composure'], top_15.iloc[2]['short_name'])
plt.text(top_15.iloc[3]['overall'], top_15.iloc[3]['mentality_composure'], top_15.iloc[3]['short_name'])
plt.text(top_15.iloc[4]['overall'], top_15.iloc[4]['mentality_composure'], top_15.iloc[4]['short_name'])
plt.text(top_15.iloc[5]['overall'], top_15.iloc[5]['mentality_composure'], top_15.iloc[5]['short_name'])
plt.text(top_15.iloc[6]['overall'], top_15.iloc[6]['mentality_composure'], top_15.iloc[6]['short_name'])
plt.text(top_15.iloc[7]['overall'], top_15.iloc[7]['mentality_composure'], top_15.iloc[7]['short_name'])
plt.text(top_15.iloc[8]['overall'], top_15.iloc[8]['mentality_composure'], top_15.iloc[8]['short_name'])
plt.text(top_15.iloc[9]['overall'], top_15.iloc[9]['mentality_composure'], top_15.iloc[9]['short_name'])

ax.set_title("Overall Rating vs Mentality Composure")
ax.set_ylabel('Mentality Composure Rating')
ax.set_xlabel('Overall Rating')

plt.show()

# %%
fifa_df.groupby(['preferred_foot']).count()[['sofifa_id']]
# Out:
#                 sofifa_id
# preferred_foot
# Left                 4565
# Right               14674

# %%
y_axis = ['defending_standing_tackle','mentality_composure','defending_marking_awareness', 'mentality_penalties', 'mentality_positioning','mentality_vision', 'mentality_interceptions', 'mentality_aggression', 'power_long_shots', 'power_stamina','power_strength', 'power_jumping', 'movement_balance','power_shot_power', 'movement_reactions', 'movement_sprint_speed','movement_agility', 'movement_acceleration', 'skill_ball_control', 'skill_long_passing', 'skill_fk_accuracy', 'skill_curve', 'skill_dribbling', 'attacking_short_passing','attacking_volleys', 'attacking_finishing','attacking_heading_accuracy', 'physic','attacking_crossing', 'defending', 'dribbling', 'passing', 'shooting','pace', 'overall',]
x_axis = ['92','89','93','81','89','35','77','84','95','90','82','86','88','81','76','77','92','87','91','87','95','71','94','95','84','78','93','63','29','95','82','84','95','32','24']

plt.style.use('ggplot')

plt.figure(figsize=(15,10))
plt.barh(y_axis,x_axis,align='center', height=0.8, color="red")
plt.title('Cristiano Ronaldo Statistics')
plt.ylabel('Skill')
plt.xlabel('Rating (out of 100)')
plt.show()

# %%
y_axis = ['defending_standing_tackle','mentality_composure','defending_marking_awareness', 'mentality_penalties', 'mentality_positioning','mentality_vision', 'mentality_interceptions', 'mentality_aggression', 'power_long_shots', 'power_stamina','power_strength', 'power_jumping', 'movement_balance','power_shot_power', 'movement_reactions', 'movement_sprint_speed','movement_agility', 'movement_acceleration', 'skill_ball_control', 'skill_long_passing', 'skill_fk_accuracy', 'skill_curve', 'skill_dribbling', 'attacking_short_passing','attacking_volleys', 'attacking_finishing','attacking_heading_accuracy', 'physic','attacking_crossing', 'defending', 'dribbling', 'passing', 'shooting','pace', 'overall',]
x_axis = ['92','89','93','81','89','35','77','84','95','90','82','86','88','81','76','77','92','87','91','87','95','71','94','95','84','78','93','63','29','95','82','84','95','32','24']

plt.style.use('ggplot')

plt.figure(figsize=(15,10))
plt.barh(y_axis,x_axis,align='center', height=0.8, color="red")
plt.title('Cristiano Ronaldo Statistics')
plt.ylabel('Skill')
plt.xlabel('Rating (out of 100)')
plt.show()

# %%
# Get best players for each position


fifa_df.club_position.unique()
# Out:
# array(['RW', 'ST', 'LW', 'RCM', 'GK', 'CF', 'CDM', 'LCB', 'RDM', 'RS',
#        'LCM', 'SUB', 'CAM', 'RCB', 'LDM', 'LB', 'RB', 'LM', 'RM', 'LS',
#        'CB', 'RES', nan, 'RWB', 'RF', 'CM', 'LWB', 'LAM', 'LF', 'RAM'],
#       dtype=object)

# %%
# fifa_df.overall.unique()

# %%
position_dictionary = dict.fromkeys(fifa_df.club_position.unique(), (1,""))

value = position_dictionary.get("RW")

for index, row in fifa_df.iterrows():
#     if position_dictionary[row['club_position']]:
    if row['club_position'] in position_dictionary:
        value = position_dictionary.get(row['club_position'])
        if row['overall'] > value[0]:
            player = (row['overall'], row['short_name'])
            position_dictionary[row['club_position']] = player

# %%
# position_dictionary = dict.fromkeys(fifa_df.club_position.unique(), (1,""))

print(position_dictionary)
# Out:
# {'RW': (93, 'L. Messi'), 'ST': (92, 'R. Lewandowski'), 'LW': (91, 'Neymar Jr'), 'RCM': (91, 'K. De Bruyne'), 'GK': (91, 'J. Oblak'), 'CF': (89, 'K. Benzema'), 'CDM': (89, 'Casemiro'), 'LCB': (89, 'V. van Dijk'), 'RDM': (89, 'J. Kimmich'), 'RS': (88, 'L. Suárez'), 'LCM': (88, 'T. Kroos'), 'SUB': (88, 'K. Navas'), 'CAM': (88, 'Bruno Fernandes'), 'RCB': (87, 'Marquinhos'), 'LDM': (87, 'L. Goretzka'), 'LB': (87, 'A. Robertson'), 'RB': (87, 'T. Alexander-Arnold'), 'LM': (87, 'J. Sancho'), 'RM': (86, 'Marcos Llorente'), 'LS': (85, 'A. Griezmann'), 'CB': (85, 'S. de Vrij'), 'RES': (83, 'J. Boateng'), nan: (83, 'T. Alderweireld'), 'RWB': (83, 'Azpilicueta'), 'RF': (83, 'K. Volland'), 'CM': (82, 'I. Gueye'), 'LWB': (82, 'Grimaldo'), 'LAM': (81, 'C. Nkunku'), 'LF': (80, 'N. Lodeiro'), 'RAM': (78, 'Guilson Paiva')}

# %%
# pace                         2132
# shooting                     2132
# passing                      2132
# dribbling                    2132
# defending                    2132
# physic   
# These are the null values for goalkeepers....
# But i'm going see how these fair against overall quality. 


fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(6, figsize=(15,10))
fig.suptitle("traits versus overall")

ax1.plot(fifa_df['pace'][0:600], fifa_df['overall'][0:600], 'b.')
ax2.plot(fifa_df['shooting'][0:600], fifa_df['overall'][0:600], 'b.')
ax3.plot(fifa_df['passing'][0:600], fifa_df['overall'][0:600], 'b.')
ax4.plot(fifa_df['dribbling'][0:600], fifa_df['overall'][0:600], 'b.')
ax5.plot(fifa_df['defending'][0:600], fifa_df['overall'][0:600], 'b.')
ax6.plot(fifa_df['physic'][0:600], fifa_df['overall'][0:600], 'b.')
