# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
import sklearn.utils
import os

# %%
file_path = "/Users/ryanreid/Documents/Machine Learning/fifa/archive/players_22.csv"

fifa_df = pd.read_csv(file_path, index_col=False)
# Out:
# /var/folders/z6/hgtgdd9502lbqgzmmg88__ym0000gn/T/ipykernel_38683/1888210308.py:3: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   fifa_df = pd.read_csv(file_path, index_col=False)

# %%
# Look at the data

fifa_df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# 0       93         93   78000000.0  320000.0   34  ...  50+3  50+3  50+3
# 1       92         92  119500000.0  270000.0   32  ...  60+3  60+3  60+3
# 2       91         91   45000000.0  270000.0   36  ...  53+3  53+3  53+3
# 3       91         91  129000000.0  270000.0   29  ...  50+3  50+3  50+3
# 4       91         91  125500000.0  350000.0   30  ...  69+3  69+3  69+3
#
#      rb    gk                                    player_face_url  \
# 0  61+3  19+3  https://cdn.sofifa.net/players/158/023/22_120.png
# 1  61+3  19+3  https://cdn.sofifa.net/players/188/545/22_120.png
# 2  60+3  20+3  https://cdn.sofifa.net/players/020/801/22_120.png
# 3  62+3  20+3  https://cdn.sofifa.net/players/190/871/22_120.png
# 4  75+3  21+3  https://cdn.sofifa.net/players/192/985/22_120.png
#
#                             club_logo_url  \
# 0  https://cdn.sofifa.net/teams/73/60.png
# 1  https://cdn.sofifa.net/teams/21/60.png
# 2  https://cdn.sofifa.net/teams/11/60.png
# 3  https://cdn.sofifa.net/teams/73/60.png
# 4  https://cdn.sofifa.net/teams/10/60.png
#
#                              club_flag_url  \
# 0      https://cdn.sofifa.net/flags/fr.png
# 1      https://cdn.sofifa.net/flags/de.png
# 2  https://cdn.sofifa.net/flags/gb-eng.png
# 3      https://cdn.sofifa.net/flags/fr.png
# 4  https://cdn.sofifa.net/flags/gb-eng.png
#
#                             nation_logo_url  \
# 0  https://cdn.sofifa.net/teams/1369/60.png
# 1  https://cdn.sofifa.net/teams/1353/60.png
# 2  https://cdn.sofifa.net/teams/1354/60.png
# 3                                       NaN
# 4  https://cdn.sofifa.net/teams/1325/60.png
#
#                        nation_flag_url
# 0  https://cdn.sofifa.net/flags/ar.png
# 1  https://cdn.sofifa.net/flags/pl.png
# 2  https://cdn.sofifa.net/flags/pt.png
# 3  https://cdn.sofifa.net/flags/br.png
# 4  https://cdn.sofifa.net/flags/be.png
#
# [5 rows x 110 columns]

# %%
# Look at the data
fifa_df.describe()
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   19239.000000  19239.000000  19239.000000  1.916500e+04   19178.000000
# mean   231468.086959     65.772182     71.079370  2.850452e+06    9017.989363
# std     27039.717497      6.880232      6.086213  7.613700e+06   19470.176724
# min        41.000000     47.000000     49.000000  9.000000e+03     500.000000
# 25%    214413.500000     61.000000     67.000000  4.750000e+05    1000.000000
# 50%    236543.000000     66.000000     71.000000  9.750000e+05    3000.000000
# 75%    253532.500000     70.000000     75.000000  2.000000e+06    8000.000000
# max    264640.000000     93.000000     95.000000  1.940000e+08  350000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  19239.000000  19239.000000  19239.000000   19178.000000  19178.000000
# mean      25.210822    181.299704     74.943032   50580.498123      1.354364
# std        4.748235      6.863179      7.069434   54401.868535      0.747865
# min       16.000000    155.000000     49.000000       1.000000      1.000000
# 25%       21.000000    176.000000     70.000000     479.000000      1.000000
# 50%       25.000000    181.000000     75.000000    1938.000000      1.000000
# 75%       29.000000    186.000000     80.000000  111139.000000      1.000000
# max       54.000000    206.000000    110.000000  115820.000000      5.000000
#
#        ...  mentality_composure  defending_marking_awareness  \
# count  ...         19239.000000                 19239.000000
# mean   ...            57.929830                    46.601746
# std    ...            12.159326                    20.200807
# min    ...            12.000000                     4.000000
# 25%    ...            50.000000                    29.000000
# 50%    ...            59.000000                    52.000000
# 75%    ...            66.000000                    63.000000
# max    ...            96.000000                    93.000000
#
#        defending_standing_tackle  defending_sliding_tackle  \
# count               19239.000000              19239.000000
# mean                   48.045584                 45.906700
# std                    21.232718                 20.755683
# min                     5.000000                  5.000000
# 25%                    28.000000                 25.000000
# 50%                    56.000000                 53.000000
# 75%                    65.000000                 63.000000
# max                    93.000000                 92.000000
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# count        19239.000000          19239.000000         19239.000000
# mean            16.406102             16.192474            16.055356
# std             17.574028             16.839528            16.564554
# min              2.000000              2.000000             2.000000
# 25%              8.000000              8.000000             8.000000
# 50%             11.000000             11.000000            11.000000
# 75%             14.000000             14.000000            14.000000
# max             91.000000             92.000000            93.000000
#
#        goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed
# count             19239.000000          19239.000000        2132.000000
# mean                 16.229274             16.491814          36.439962
# std                  17.059779             17.884833          10.751563
# min                   2.000000              2.000000          15.000000
# 25%                   8.000000              8.000000          27.000000
# 50%                  11.000000             11.000000          36.000000
# 75%                  14.000000             14.000000          45.000000
# max                  92.000000             90.000000          65.000000
#
# [8 rows x 60 columns]

# %%
# Look at the data
fifa_df.shape
# Out:
# (19239, 110)

# %%
# Look at the data
fifa_df.dtypes
# Out:
# sofifa_id            int64
# player_url          object
# short_name          object
# long_name           object
# player_positions    object
#                      ...
# player_face_url     object
# club_logo_url       object
# club_flag_url       object
# nation_logo_url     object
# nation_flag_url     object
# Length: 110, dtype: object

# %%
# Look at the data
fifa_df.count()
# Out:
# sofifa_id           19239
# player_url          19239
# short_name          19239
# long_name           19239
# player_positions    19239
#                     ...
# player_face_url     19239
# club_logo_url       19178
# club_flag_url       19178
# nation_logo_url       759
# nation_flag_url     19239
# Length: 110, dtype: int64

# %%
# Look at the data
n = len(pd.unique(fifa_df['sofifa_id']))
print("number of unique vales: ", n)
# Out:
# number of unique vales:  19239

# %%
missing_data = fifa_df.isnull().sum()


print(missing_data[missing_data > 0])
# Out:
# value_eur                       74
# wage_eur                        61
# club_team_id                    61
# club_name                       61
# league_name                     61
# league_level                    61
# club_position                   61
# club_jersey_number              61
# club_loaned_from             18137
# club_joined                   1163
# club_contract_valid_until       61
# nation_team_id               18480
# nation_position              18480
# nation_jersey_number         18480
# release_clause_eur            1176
# player_tags                  17798
# player_traits                 9841
# pace                          2132
# shooting                      2132
# passing                       2132
# dribbling                     2132
# defending                     2132
# physic                        2132
# goalkeeping_speed            17107
# club_logo_url                   61
# club_flag_url                   61
# nation_logo_url              18480
# dtype: int64

# %%
fifa_df['player_positions'].value_counts()
# Out:
# CB              2423
# GK              2132
# ST              1770
# CDM, CM          953
# CM               726
#                 ...
# CAM, CDM, ST       1
# CDM, RWB, CB       1
# ST, CAM, RW        1
# ST, CF, RM         1
# CDM, LM, LB        1
# Name: player_positions, Length: 674, dtype: int64

# %%
fifa_df.club_position.unique()
# Out:
# array(['RW', 'ST', 'LW', 'RCM', 'GK', 'CF', 'CDM', 'LCB', 'RDM', 'RS',
#        'LCM', 'SUB', 'CAM', 'RCB', 'LDM', 'LB', 'RB', 'LM', 'RM', 'LS',
#        'CB', 'RES', nan, 'RWB', 'RF', 'CM', 'LWB', 'LAM', 'LF', 'RAM'],
#       dtype=object)

# %%
fifa_df.player_positions.unique()
# Out:
# array(['RW, ST, CF', 'ST', 'ST, LW', 'LW, CAM', 'CM, CAM', 'GK',
#        'CDM, CM', 'CF, ST', 'LM, CF, LW', 'CDM', 'CB', 'LW', 'RW',
#        'CDM, RB', 'CM', 'LW, RW', 'CAM', 'RW, LW', 'CAM, RM, RW',
#        'CM, LM', 'CB, CDM', 'CM, CDM', 'CF, CAM', 'LB', 'CM, CDM, CB',
#        'RB', 'RM, CF, LM', 'LB, LM', 'LW, CF', 'RW, RM', 'ST, RM, RW',
#        'CDM, CB', 'RB, LB', 'LM, RM, LW', 'CAM, CM, RW', 'CM, RM, ST',
#        'CAM, CF, CM', 'CAM, CM', 'CAM, CF', 'ST, LW, LM', 'ST, LW, RW',
#        'CF', 'CF, LW, CAM', 'RM, LM, RW', 'CM, CDM, CAM', 'LM, ST',
#        'RB, RWB', 'RB, RM', 'CF, ST, CAM', 'RB, RWB, RM', 'ST, RW',
#        'CB, LB', 'CAM, CM, CF', 'LW, CF, CAM', 'LW, LM, CAM', 'LM, LWB',
#        'RW, CAM', 'CAM, RM, ST', 'RM, LM', 'CAM, LW, CM', 'RW, LW, CAM',
#        'CB, RWB', 'CM, CAM, CDM', 'CAM, RM, LM', 'CM, CDM, LM',
#        'CF, RM, RW', 'ST, CF', 'LWB, LB, LM', 'LB, LWB, LM', 'LM, CM, RM',
#        'ST, RM', 'ST, CAM', 'LWB, LM', 'LB, CB', 'CAM, RM', 'RW, LW, RM',
#        'RM, RW', 'CAM, ST', 'CAM, CM, LW', 'CB, CDM, LB', 'RM, RB, RW',
#        'CF, LM, ST', 'CM, LM, RM', 'LM, CF', 'RW, RM, LW', 'CAM, LM',
#        'CM, CB, CDM', 'LB, LM, LWB', 'CB, RB', 'CM, CF', 'LW, ST',
#        'LW, RW, LM', 'RM, RW, LW', 'LWB, LB', 'CAM, CM, CDM', 'RW, ST',
#        'LW, LM', 'LM, LW, LWB', 'CM, RM', 'RW, CAM, CM', 'RB, LB, CB',
#        'RB, CM, RM', 'CB, RB, LB', 'RM, CF', 'RW, RB, RM', 'LM, RM, CM',
#        'LM, RM, ST', 'ST, LM', 'RWB, RB, RM', 'CDM, CM, CB', 'LM, ST, CF',
#        'CDM, CM, RB', 'RWB, CB, RM', 'CDM, CM, CAM', 'CF, CM',
#        'CM, RM, LM', 'LM, LW', 'RWB', 'RWB, RB', 'LM, LB', 'RW, CM',
#        'RW, CF', 'RB, RM, CM', 'CM, CAM, LM', 'CM, CDM, RM', 'CM, LM, CF',
#        'CAM, LW, RW', 'CAM, LW', 'LWB, RWB', 'RM, LM, ST', 'CB, RB, RWB',
#        'LM, CAM', 'LM', 'LM, LW, RM', 'LB, CB, LWB', 'LB, CDM',
#        'CAM, LM, LW', 'RM, RB, CM', 'RWB, RM', 'RM', 'RM, LM, LB',
#        'CM, LB, RB', 'CF, LW', 'RM, RWB', 'CAM, RW', 'ST, RW, CAM',
#        'CAM, ST, CM', 'LM, RM', 'LM, ST, RM', 'RB, RM, LB', 'CAM, LM, RM',
#        'RWB, RM, LM', 'LW, RW, ST', 'RWB, LWB, CB', 'CM, CAM, CF',
#        'LM, RM, CAM', 'RB, CB', 'CB, CM, CDM', 'RM, ST', 'LM, CM',
#        'LB, LWB', 'CB, LB, CDM', 'CAM, LM, ST', 'RM, CAM', 'CDM, CM, LM',
#        'RWB, LWB, RB', 'CF, RW', 'LB, RB', 'CM, LM, LW', 'CAM, CF, LM',
#        'RM, LM, CM', 'CDM, CB, CM', 'CB, CM', 'CDM, LB', 'CDM, CM, RM',
#        'RW, RWB', 'LB, LWB, CB', 'RM, RB', 'LW, RW, CAM', 'CAM, CM, RM',
#        'CAM, LW, LM', 'RW, RM, ST', 'CM, CAM, LW', 'CAM, LM, CM',
#        'LM, ST, CAM', 'RM, LM, LW', 'ST, RW, LW', 'ST, LW, CAM',
#        'RM, CM, CAM', 'CAM, CM, LM', 'RB, RM, RW', 'RWB, RM, RB',
#        'RM, RWB, CM', 'RM, CM', 'RB, RM, LM', 'CAM, ST, LW', 'LM, LW, ST',
#        'CM, LW', 'RB, RWB, LB', 'CM, CB', 'RM, LW', 'LB, RB, LM',
#        'CF, CAM, LM', 'LM, CF, RM', 'RM, RW, CM', 'CM, ST, LM',
#        'CF, LM, RM', 'LB, RB, CB', 'LB, LM, CAM', 'LM, CAM, ST',
#        'CDM, RWB', 'RWB, RW', 'LM, RW', 'LW, ST, LM', 'LM, RM, CF',
#        'ST, LM, CAM', 'RM, RW, CF', 'CM, RM, CDM', 'CDM, RB, CB',
#        'RM, CAM, RW', 'CB, LB, LM', 'LW, LM, CF', 'CM, CDM, RB',
#        'CM, RM, CAM', 'RM, RW, ST', 'LM, LW, CM', 'CAM, LW, ST',
#        'RB, RM, RWB', 'LWB, LB, RB', 'RM, CAM, ST', 'LB, LW',
#        'RM, LW, CAM', 'CB, RB, CDM', 'LM, RW, LW', 'LM, CAM, RM',
#        'LWB, LB, CB', 'RB, LB, RM', 'LM, CAM, CM', 'RM, LM, CAM',
#        'RM, LW, LM', 'RM, CM, ST', 'LW, LM, ST', 'RB, CB, CDM',
#        'LW, ST, RW', 'ST, LM, RM', 'CF, CAM, ST', 'CDM, CAM, CM',
#        'CB, LB, RM', 'CM, CAM, RW', 'CDM, CM, LB', 'RM, CM, RW', 'RB, CM',
#        'LW, CF, ST', 'LM, CM, LWB', 'RM, LB, RB', 'LM, ST, LW',
#        'CAM, CDM, LM', 'CB, LB, RB', 'CAM, CF, ST', 'RW, CAM, CF',
#        'LW, CAM, ST', 'LWB, RW, RM', 'ST, LM, CM', 'RM, CM, LB',
#        'RW, CAM, LW', 'CF, LW, ST', 'RW, RM, CM', 'RM, LWB, LB', 'LB, CM',
#        'RW, CAM, LM', 'RM, ST, LM', 'ST, RM, LM', 'CM, CF, CAM',
#        'RM, RB, RWB', 'CDM, RB, RWB', 'LB, LM, LW', 'RM, RW, LM',
#        'RW, ST, LM', 'CDM, RM', 'ST, LM, LW', 'RB, CDM', 'LW, RM, RW',
#        'CM, RW, LW', 'LWB, LM, LB', 'CAM, RM, CM', 'LB, LM, CM',
#        'LM, ST, CM', 'RW, LW, CF', 'LWB', 'CB, CDM, CM', 'CF, LM, CAM',
#        'RM, RW, CAM', 'CAM, CDM', 'LB, CM, LM', 'LW, LM, RW',
#        'RW, ST, RM', 'CB, RB, RM', 'LM, RM, RW', 'ST, CAM, CDM',
#        'CF, RW, ST', 'CAM, ST, LM', 'LWB, LB, LW', 'RW, LW, ST',
#        'ST, CAM, LM', 'LB, CAM, LM', 'RW, RM, CAM', 'RW, CAM, RM',
#        'RB, CB, LB', 'RM, CAM, LM', 'RM, ST, RWB', 'LM, CM, CAM',
#        'ST, CAM, RM', 'CM, CAM, RM', 'RW, LM', 'CF, LM', 'RB, RWB, CB',
#        'LB, CM, RB', 'RB, CB, RWB', 'RB, RWB, LWB', 'LB, LWB, RB',
#        'LWB, CB, LB', 'CAM, CM, ST', 'LM, LB, LWB', 'CAM, ST, CF',
#        'LM, CAM, LW', 'CM, CF, RM', 'LW, LM, LWB', 'LM, LW, CAM',
#        'CAM, CDM, CM', 'ST, RM, CAM', 'CM, CAM, RWB', 'RB, CB, RM',
#        'RM, ST, RW', 'LM, CF, CAM', 'CM, LB', 'LB, LM, CB', 'RM, LM, CF',
#        'ST, CF, CAM', 'RM, RWB, CAM', 'RM, CM, LM', 'CDM, CAM, RB',
#        'LB, LWB, LW', 'CAM, RW, CM', 'ST, CAM, CM', 'CAM, CF, RM',
#        'CAM, CF, LW', 'ST, LW, CF', 'CAM, RW, LW', 'RWB, RB, LWB',
#        'ST, CF, LW', 'LWB, CB', 'RM, RB, LM', 'RB, RW', 'RWB, RM, LWB',
#        'LM, CAM, CF', 'RM, LM, RB', 'LWB, CM', 'LM, RM, LWB',
#        'CAM, ST, RW', 'RM, RB, ST', 'CF, ST, LM', 'LW, LWB, RWB',
#        'CM, LW, RW', 'RM, ST, CM', 'LM, LB, LW', 'LW, CM, CAM',
#        'LM, LW, RW', 'CAM, RM, RB', 'CDM, RB, RM', 'CAM, CM, RWB',
#        'RM, CAM, CM', 'CF, RM, CAM', 'CDM, RM, CM', 'ST, CAM, LW',
#        'CDM, CM, ST', 'CM, RW', 'LW, CAM, RW', 'LB, CDM, CB',
#        'RWB, RB, CB', 'CM, LM, LWB', 'ST, RW, RM', 'RM, RWB, ST',
#        'LWB, CM, RW', 'LB, LM, RB', 'LM, ST, LB', 'RWB, RB, LB',
#        'RB, CDM, LB', 'CF, RM, ST', 'LM, LB, RM', 'RB, LB, RWB',
#        'CAM, LM, RW', 'CAM, ST, RM', 'LM, CM, CDM', 'CM, RM, RB',
#        'CF, LM, CM', 'CM, RB', 'CAM, RW, ST', 'CAM, LM, CF', 'LW, LM, LB',
#        'LB, LW, LM', 'CB, RM', 'CF, RM', 'CDM, CAM', 'LB, LWB, CDM',
#        'RM, RB, LB', 'RWB, RB, CM', 'RM, LWB', 'LM, LB, CAM',
#        'LM, LWB, LW', 'LB, CB, RM', 'LB, RB, RWB', 'RB, CM, RWB',
#        'LM, RM, LB', 'ST, CAM, CF', 'CM, LM, CAM', 'RB, LM', 'RW, ST, LW',
#        'CB, CDM, RB', 'CAM, RB', 'LB, CM, CDM', 'CF, ST, LW',
#        'CM, CDM, LB', 'LWB, LW, LM', 'CAM, LW, CF', 'CDM, LM',
#        'LB, RB, LW', 'LB, CB, LM', 'CDM, CAM, LM', 'RB, LM, RM',
#        'CM, LM, CDM', 'RB, LB, LM', 'CDM, RB, CM', 'CDM, LB, CB',
#        'RW, LW, LM', 'CB, LB, LWB', 'LB, LM, CDM', 'LW, CM',
#        'CDM, CB, RB', 'CM, CAM, ST', 'RB, CDM, CB', 'CB, LWB, LB',
#        'CB, LB, CM', 'ST, CM, RW', 'LW, LM, RM', 'RW, LW, CM',
#        'RW, RM, CF', 'CM, LM, LB', 'RB, LB, CDM', 'RM, LM, RWB',
#        'ST, CF, RW', 'RB, CM, CAM', 'CM, CF, ST', 'LM, RW, RM',
#        'CM, LM, ST', 'LB, CB, RB', 'RB, RWB, CM', 'RB, CDM, CM',
#        'LWB, LW', 'CM, CAM, CB', 'RM, ST, CAM', 'CM, CDM, ST',
#        'RB, RM, CB', 'CAM, CF, RW', 'RM, CB', 'LW, RM, LM', 'CF, CAM, LW',
#        'LM, CM, CF', 'CM, RWB, RW', 'LM, LB, RB', 'ST, RM, CF',
#        'RM, LM, CDM', 'RM, RWB, RB', 'CM, CDM, LW', 'LW, LWB, LM',
#        'LB, RB, RM', 'CM, LW, CDM', 'RB, RWB, CDM', 'LB, ST, CAM',
#        'CM, RB, LB', 'CM, RB, CDM', 'LM, CF, ST', 'CAM, RW, CF',
#        'CB, CAM', 'LM, LW, CF', 'RM, ST, RB', 'LW, RW, RM', 'CB, RWB, RB',
#        'LWB, LB, RWB', 'RWB, LWB', 'CF, CM, ST', 'RW, LM, RM',
#        'RM, RW, RWB', 'CAM, CDM, ST', 'LB, LM, RM', 'LM, RWB',
#        'LB, CDM, LM', 'RB, RWB, RW', 'LB, LWB, CM', 'CDM, RWB, CB',
#        'ST, CAM, RW', 'RW, RB', 'ST, CF, RM', 'RM, CF, ST', 'LM, LWB, ST',
#        'LB, RM', 'CM, CDM, CF', 'LM, LWB, RM', 'CM, CDM, LWB',
#        'LM, LWB, LB', 'RW, ST, CAM', 'LM, CAM, LWB', 'LM, RW, ST',
#        'RWB, RM, CDM', 'LM, CM, ST', 'LM, ST, RW', 'CM, CB, CF',
#        'LWB, LM, CB', 'CAM, CDM, RM', 'CF, ST, RW', 'RWB, CB',
#        'RW, RM, RB', 'RW, LWB, RWB', 'CM, LW, ST', 'RW, CAM, ST',
#        'CDM, LM, CM', 'LM, CAM, LB', 'CF, CM, CDM', 'CF, RM, LM',
#        'ST, LW, RM', 'CB, RWB, RM', 'LB, CM, ST', 'RWB, LWB, CM',
#        'RM, CF, RB', 'CF, CAM, CM', 'LB, RM, LM', 'CDM, LB, RB',
#        'RB, CB, ST', 'LM, CM, LW', 'CF, CAM, RM', 'LB, CB, CDM',
#        'CM, LW, CAM', 'RB, CB, LM', 'CM, RB, RW', 'CB, LWB',
#        'CM, LWB, CDM', 'RB, CDM, RM', 'CB, LWB, LM', 'LW, CAM, CM',
#        'RB, CM, CDM', 'LW, LM, CM', 'LM, LB, CM', 'RW, RM, LM',
#        'LB, RB, CM', 'CB, CM, RB', 'RB, LB, LWB', 'LB, LW, CM',
#        'CDM, RB, LB', 'CM, CAM, LB', 'CM, ST, CDM', 'LW, RM, CM',
#        'RB, RW, LW', 'RM, ST, LW', 'RM, LW, RW', 'RW, LM, ST',
#        'CB, RB, LM', 'CM, RM, RW', 'LW, LB, LM', 'LM, RB', 'RM, CAM, CF',
#        'LM, ST, LWB', 'RB, ST', 'RM, ST, LB', 'LM, LB, CB', 'CB, LM, RM',
#        'LB, LM, CF', 'RW, CAM, LB', 'CAM, RM, CF', 'CDM, CAM, RM',
#        'RW, CF, CAM', 'LM, RB, LW', 'RM, RW, RB', 'LM, RB, RM', 'CB, ST',
#        'CB, RB, CM', 'CM, CF, LM', 'CM, LB, CDM', 'CAM, RM, RWB',
#        'RM, CAM, CB', 'LW, LB', 'RB, CAM, RM', 'RB, LW, RWB',
#        'RB, RM, CAM', 'RM, RW, CDM', 'ST, CB', 'CAM, RWB, CM',
#        'RM, CDM, RB', 'CM, RWB', 'LB, RB, CDM', 'CM, RB, RM', 'LW, LWB',
#        'LM, RB, CM', 'LM, CDM', 'RWB, CB, RB', 'RWB, CM', 'CM, RW, CAM',
#        'RWB, LW, RW', 'LM, RM, RWB', 'LM, CDM, CM', 'RB, CB, CM',
#        'CDM, CB, RM', 'LW, RM, ST', 'ST, RW, LM', 'RM, CDM, RWB',
#        'CDM, CB, LB', 'CAM, ST, CDM', 'CAM, RW, RM', 'LM, CM, RW',
#        'LB, ST', 'CM, CF, CDM', 'LW, RM', 'LW, RW, LB', 'LB, RM, CM',
#        'CB, CF', 'RW, CF, RM', 'RWB, RB, ST', 'CAM, CM, LWB',
#        'ST, LM, LB', 'LWB, ST', 'LWB, LM, RM', 'CDM, CM, RWB',
#        'RWB, CM, LWB', 'LWB, RWB, LW', 'CDM, LB, LM', 'RM, CM, CDM',
#        'RW, RM, LWB', 'LM, LWB, CF', 'LW, RW, RB', 'CF, RM, CM',
#        'LM, CM, LB', 'RM, CM, RWB', 'CM, ST', 'RM, RWB, RW', 'LM, LW, LB',
#        'RB, CAM', 'LWB, CAM', 'RWB, CDM', 'CAM, LW, LB', 'LW, CF, RW',
#        'LM, RM, RB', 'RW, LB', 'CB, LM', 'LW, RW, CM', 'LW, CAM, CF',
#        'CB, RM, RB', 'CB, LB, RWB', 'RM, LM, LWB', 'LB, CAM, CM',
#        'RWB, LWB, RW', 'CM, LWB', 'LB, LW, RW', 'CM, LM, RB',
#        'CB, LWB, RWB', 'CF, RW, LW', 'CM, RW, RM', 'RM, CAM, RWB',
#        'RM, ST, CF', 'CM, LW, LB', 'LW, LWB, RB', 'LW, RW, CF',
#        'LW, LWB, RW', 'LWB, RB', 'RW, ST, RB', 'ST, CM', 'CDM, LM, LB'],
#       dtype=object)

# %% [markdown]
# ## Notes on data so far
#
# - player_postions doesn't have any nan, SUBs or res values; it appears to be the source of truth.
# Fox example, there are players who only play for national teams or only a club. In club position
# tabel we see values, nan, subs or res.
# - if we look at the null numbers for pace, shooting, passing etc, it is the same number of goalkeepers
# in the game i.e. 2132.
# - Based on my intuition (and from years of playing FIFA, i reckon there is probably tables we can just drop
# as they won't have an affect on the overall player's rating - i.e.:
# *value_eur                       66
# *wage_eur                        53
# *club_team_id                    53
# *club_name                       53
# *league_name                     53
# *league_level                    53
# *club_position                   53
# *club_jersey_number              53
# *club_loaned_from             16086
# *club_joined                   1074
# *club_contract_valid_until       53
# *nation_team_id               16447
# *nation_position              16447
# *nation_jersey_number         16447
# *release_clause_eur            1087
# *player_tags                  15666
# *player_traits                 8530
# *goalkeeping_speed            17107
# *club_logo_url                   53
# *club_flag_url                   53
# *nation_logo_url              16447
# - On closer inspection, i don't think the model would like the work rate as it is i.e. high/low so i'm going to split this up. I am going to split this up into attacking work rate and defending work rate.
#
# - With assessing the data, it would appear that GKs and outfield each have different stats. For example, outfield players have values for shooting, pace, dribbling whereas goalkeepers do not. This would be probably make it really easyfor the model to guess which player is an outfield palyer.
#
# Another example is that goalkeepers have a goalkeeping speed stat whereas outfield players do not. The datasets i have seen normally don't have that. So i can mark them as means or just put zeros in them. Eitherway, I believe its going to balance each other when it comes to training.  I checked mean and min. I opted for min values as it was making outfield players seem to be ok GK.
#
# - I don't like how this data is all sortin an descending order of overall quality. Need to randomize that for data sets.
#
# - Just had a thought...I think height+weight might be valid data to keep so lets investgate.
#
# Tasks:
# * Create classifier target that determines player is outfield or goalkeeper aka 1 - 0
# * Have a look at height
# * Drop out columns that are not needed.
# * fix null values:  zeros or means.

# %%
# convert work rate column to numbers
def split_work_rate(x):
    
    work_rate_dict = { "High" : 5, "Medium" : 3, "Low" : 1}
    
    split = x.split("/")
    
    return work_rate_dict.get(split[0]), work_rate_dict.get(split[1])

# %%
fifa_df["attacking_work_rate"], fifa_df["defending_work_rate"] = zip(*fifa_df['work_rate'].map(split_work_rate))

# %%
# * Create classifier target that determines player is outfield or goalkeeper aka 1 - 0

# ********************************************************************************************
# https://stackoverflow.com/questions/34023918/make-new-column-in-panda-dataframe-by-adding-values-from-other-columns
# https://stackoverflow.com/questions/26886653/pandas-create-new-column-based-on-values-from-other-columns-apply-a-function-o

# %%
def get_target(x):
    if x == 'GK':
        return 0
    else:
        return 1

# %%
fifa_df['outfield'] = fifa_df['player_positions'].apply(lambda x: get_target(x))

# %%
# * Have a look at height

# ********************************************************************************************
# https://stackoverflow.com/questions/30482071/how-to-calculate-mean-values-grouped-on-another-column-in-pandas

# %%
fifa_df['height_cm'].mean()
# Out:
# 181.29970372680492

# %%
fifa_df.groupby('outfield')['height_cm'].mean()
# Out:
# outfield
# 0    188.533771
# 1    180.398141
# Name: height_cm, dtype: float64

# %%
#  Interesting Goalkeepers tend to be taller on average, and heavier.

# %%
fifa_df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age  ...    rb    gk  \
# 0       93         93   78000000.0  320000.0   34  ...  61+3  19+3
# 1       92         92  119500000.0  270000.0   32  ...  61+3  19+3
# 2       91         91   45000000.0  270000.0   36  ...  60+3  20+3
# 3       91         91  129000000.0  270000.0   29  ...  62+3  20+3
# 4       91         91  125500000.0  350000.0   30  ...  75+3  21+3
#
#                                      player_face_url  \
# 0  https://cdn.sofifa.net/players/158/023/22_120.png
# 1  https://cdn.sofifa.net/players/188/545/22_120.png
# 2  https://cdn.sofifa.net/players/020/801/22_120.png
# 3  https://cdn.sofifa.net/players/190/871/22_120.png
# 4  https://cdn.sofifa.net/players/192/985/22_120.png
#
#                             club_logo_url  \
# 0  https://cdn.sofifa.net/teams/73/60.png
# 1  https://cdn.sofifa.net/teams/21/60.png
# 2  https://cdn.sofifa.net/teams/11/60.png
# 3  https://cdn.sofifa.net/teams/73/60.png
# 4  https://cdn.sofifa.net/teams/10/60.png
#
#                              club_flag_url  \
# 0      https://cdn.sofifa.net/flags/fr.png
# 1      https://cdn.sofifa.net/flags/de.png
# 2  https://cdn.sofifa.net/flags/gb-eng.png
# 3      https://cdn.sofifa.net/flags/fr.png
# 4  https://cdn.sofifa.net/flags/gb-eng.png
#
#                             nation_logo_url  \
# 0  https://cdn.sofifa.net/teams/1369/60.png
# 1  https://cdn.sofifa.net/teams/1353/60.png
# 2  https://cdn.sofifa.net/teams/1354/60.png
# 3                                       NaN
# 4  https://cdn.sofifa.net/teams/1325/60.png
#
#                        nation_flag_url attacking_work_rate  \
# 0  https://cdn.sofifa.net/flags/ar.png                   3
# 1  https://cdn.sofifa.net/flags/pl.png                   5
# 2  https://cdn.sofifa.net/flags/pt.png                   5
# 3  https://cdn.sofifa.net/flags/br.png                   5
# 4  https://cdn.sofifa.net/flags/be.png                   5
#
#    defending_work_rate outfield
# 0                    1        1
# 1                    3        1
# 2                    1        1
# 3                    3        1
# 4                    5        1
#
# [5 rows x 113 columns]

# %%
#  Drop out columns that are not needed.

# ********************************************************************************************
# https://stackoverflow.com/questions/40636514/selecting-columns-by-list-and-columns-are-subset-of-list
# https://stackoverflow.com/questions/34682828/extracting-specific-selected-columns-to-new-dataframe-as-a-copy

# %%
keep_columns = ['overall',
'potential',
'height_cm',
'weight_kg',
'pace',
'shooting',
'passing',
'dribbling',
'defending',
'physic',
'attacking_crossing',
'attacking_finishing',
'attacking_heading_accuracy',
'attacking_short_passing',
'attacking_volleys',
'skill_dribbling',
'skill_curve',
'skill_fk_accuracy',
'skill_long_passing',
'skill_ball_control',
'movement_acceleration',
'movement_sprint_speed',
'movement_agility',
'movement_reactions',
'movement_balance',
'power_shot_power',
'power_jumping',
'power_stamina',
'power_strength',
'power_long_shots',
'mentality_aggression',
'mentality_interceptions',
'mentality_positioning',
'mentality_vision',
'mentality_penalties',
'mentality_composure',
'defending_marking_awareness',
'defending_standing_tackle',
'defending_sliding_tackle',
'goalkeeping_diving',
'goalkeeping_handling',
'goalkeeping_kicking',
'goalkeeping_positioning',
'goalkeeping_reflexes',
'goalkeeping_speed',
'attacking_work_rate',
'defending_work_rate',
'outfield']

# %%
fifa_df.shape # Verification
# Out:
# (19239, 113)

# %%
fifa_df = fifa_df[[*keep_columns]]

# %%
fifa_df.shape # Verification
# Out:
# (19239, 48)

# %%
# fix null values: zeros or means.
#  Have a check on missing data: 

# ********************************************************************************************

# %%
missing_data = fifa_df.isnull().sum()


print(missing_data[missing_data > 0])
# Out:
# pace                  2132
# shooting              2132
# passing               2132
# dribbling             2132
# defending             2132
# physic                2132
# goalkeeping_speed    17107
# dtype: int64

# %%
# Task 1 - Lets also check to make sure we have no nulls again 
# Task 2 - So we have our data table so far. It needs rearranged so target column is at the back. 
# Task 3 - We also need randomize it - it is currently sorted in overall value (descending order)
# Task 4 - We will then save our engineered data. 
# Task 5 - After that lets break it out train, test, valid data sets.

# %%
# Task 1 - Lets also check to make sure we have no nulls again 
fifa_df.isnull().sum()
# Out:
# overall                            0
# potential                          0
# height_cm                          0
# weight_kg                          0
# pace                            2132
# shooting                        2132
# passing                         2132
# dribbling                       2132
# defending                       2132
# physic                          2132
# attacking_crossing                 0
# attacking_finishing                0
# attacking_heading_accuracy         0
# attacking_short_passing            0
# attacking_volleys                  0
# skill_dribbling                    0
# skill_curve                        0
# skill_fk_accuracy                  0
# skill_long_passing                 0
# skill_ball_control                 0
# movement_acceleration              0
# movement_sprint_speed              0
# movement_agility                   0
# movement_reactions                 0
# movement_balance                   0
# power_shot_power                   0
# power_jumping                      0
# power_stamina                      0
# power_strength                     0
# power_long_shots                   0
# mentality_aggression               0
# mentality_interceptions            0
# mentality_positioning              0
# mentality_vision                   0
# mentality_penalties                0
# mentality_composure                0
# defending_marking_awareness        0
# defending_standing_tackle          0
# defending_sliding_tackle           0
# goalkeeping_diving                 0
# goalkeeping_handling               0
# goalkeeping_kicking                0
# goalkeeping_positioning            0
# goalkeeping_reflexes               0
# goalkeeping_speed              17107
# attacking_work_rate                0
# defending_work_rate                0
# outfield                           0
# dtype: int64

# %%
##-----   Code to deal with nan values  -----##

# helper function to fill NaN values with a column average
def fill_nan_with_min(df):
    '''Fills NaN values in a given dataframe with the min values in a column.
    
       :param df: a DataFrame that is assumed to contain cols of float values
       :return: returns a DataFrame with all null values replaced with the min val for a column'''
    
    # filling nan with mean value of any columns
    for col in list(df.columns.values):  
        # ignoring date/time cols
        if col != 'Date' and col != 'Time':
            df[col].iloc[:]=df[col].iloc[:].fillna(df[col].iloc[:].min())
        
    return df


# Note: going to ignore SettingWithCopyWarning for now
fifa_df = fill_nan_with_min(fifa_df)

# %%
fifa_df.isnull().sum()
# Out:
# overall                        0
# potential                      0
# height_cm                      0
# weight_kg                      0
# pace                           0
# shooting                       0
# passing                        0
# dribbling                      0
# defending                      0
# physic                         0
# attacking_crossing             0
# attacking_finishing            0
# attacking_heading_accuracy     0
# attacking_short_passing        0
# attacking_volleys              0
# skill_dribbling                0
# skill_curve                    0
# skill_fk_accuracy              0
# skill_long_passing             0
# skill_ball_control             0
# movement_acceleration          0
# movement_sprint_speed          0
# movement_agility               0
# movement_reactions             0
# movement_balance               0
# power_shot_power               0
# power_jumping                  0
# power_stamina                  0
# power_strength                 0
# power_long_shots               0
# mentality_aggression           0
# mentality_interceptions        0
# mentality_positioning          0
# mentality_vision               0
# mentality_penalties            0
# mentality_composure            0
# defending_marking_awareness    0
# defending_standing_tackle      0
# defending_sliding_tackle       0
# goalkeeping_diving             0
# goalkeeping_handling           0
# goalkeeping_kicking            0
# goalkeeping_positioning        0
# goalkeeping_reflexes           0
# goalkeeping_speed              0
# attacking_work_rate            0
# defending_work_rate            0
# outfield                       0
# dtype: int64

# %%
# Convert single column to int dtype.
fifa_df['pace'] = fifa_df['pace'].astype('int')
fifa_df['shooting'] = fifa_df['shooting'].astype('int')
fifa_df['passing'] = fifa_df['passing'].astype('int')
fifa_df['dribbling'] = fifa_df['dribbling'].astype('int')
fifa_df['defending'] = fifa_df['defending'].astype('int')
fifa_df['physic'] = fifa_df['physic'].astype('int')
fifa_df['goalkeeping_speed'] = fifa_df['goalkeeping_speed'].astype('int')

# %%
fifa_df.head(30)
# Out:
#     overall  potential  height_cm  weight_kg  pace  shooting  passing  \
# 0        93         93        170         72    85        92       91
# 1        92         92        185         81    78        92       79
# 2        91         91        187         83    87        94       80
# 3        91         91        175         68    91        83       86
# 4        91         91        181         70    76        86       93
# 5        91         93        188         87    28        18       25
# 6        91         95        182         73    97        88       80
# 7        90         90        193         93    28        18       25
# 8        90         92        187         85    28        18       25
# 9        90         90        188         89    70        91       83
# 10       90         90        168         70    78        66       75
# 11       89         89        185         81    76        86       81
# 12       89         91        199         96    28        18       25
# 13       89         89        183         78    88        87       82
# 14       89         89        185         84    65        73       76
# 15       89         89        193         92    78        60       71
# 16       89         89        175         69    91        83       80
# 17       89         89        175         71    90        87       81
# 18       89         91        188         86    28        18       25
# 19       89         90        177         75    70        73       86
# 20       89         90        191         91    28        18       25
# 21       89         93        196         90    28        18       25
# 22       88         88        184         82    70        70       76
# 23       88         88        182         83    72        90       82
# 24       88         88        183         76    53        81       91
# 25       88         88        191         94    84        87       74
# 26       88         88        185         80    28        18       25
# 27       88         89        170         69    91        82       79
# 28       88         89        179         69    75        86       89
# 29       88         93        194         94    89        91       65
#
#     dribbling  defending  physic  ...  defending_sliding_tackle  \
# 0          95         34      65  ...                        24
# 1          86         44      82  ...                        19
# 2          88         34      75  ...                        24
# 3          94         37      63  ...                        29
# 4          88         64      78  ...                        53
# 5          27         14      29  ...                        18
# 6          92         36      77  ...                        32
# 7          27         14      29  ...                        11
# 8          27         14      29  ...                        10
# 9          83         47      83  ...                        38
# 10         82         87      83  ...                        86
# 11         87         39      77  ...                        18
# 12         27         14      29  ...                        16
# 13         86         43      69  ...                        33
# 14         73         86      90  ...                        87
# 15         72         91      84  ...                        86
# 16         89         44      77  ...                        38
# 17         90         45      75  ...                        41
# 18         27         14      29  ...                         8
# 19         84         83      79  ...                        79
# 20         27         14      29  ...                        16
# 21         27         14      29  ...                        16
# 22         74         88      84  ...                        91
# 23         84         47      83  ...                        38
# 24         81         71      68  ...                        60
# 25         78         39      83  ...                        30
# 26         27         14      29  ...                        14
# 27         87         45      66  ...                        47
# 28         84         70      77  ...                        65
# 29         80         45      88  ...                        30
#
#     goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                    6                    11                   15
# 1                   15                     6                   12
# 2                    7                    11                   15
# 3                    9                     9                   15
# 4                   15                    13                    5
# 5                   87                    92                   78
# 6                   13                     5                    7
# 7                   88                    88                   91
# 8                   88                    85                   88
# 9                    8                    10                   11
# 10                  15                    12                   10
# 11                  13                    11                    5
# 12                  84                    89                   74
# 13                  11                    13                   13
# 14                  13                    14                   16
# 15                  13                    10                   13
# 16                  10                    10                   15
# 17                  14                    14                    9
# 18                  87                    82                   93
# 19                   8                    15                    7
# 20                  86                    86                   84
# 21                  91                    83                   79
# 22                  11                     8                    9
# 23                  27                    25                   31
# 24                  10                    11                   13
# 25                   8                    15                   14
# 26                  89                    84                   75
# 27                  15                    12                   12
# 28                  12                    14                   15
# 29                   7                    14                   13
#
#     goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed  \
# 0                        14                     8                 15
# 1                         8                    10                 15
# 2                        14                    11                 15
# 3                        15                    11                 15
# 4                        10                    13                 15
# 5                        90                    90                 50
# 6                        11                     6                 15
# 7                        89                    88                 56
# 8                        88                    90                 43
# 9                        14                    11                 15
# 10                        7                    10                 15
# 11                        5                     7                 15
# 12                       86                    88                 46
# 13                        6                    10                 15
# 14                       12                    12                 15
# 15                       11                    11                 15
# 16                        7                    14                 15
# 17                       11                    14                 15
# 18                       88                    88                 64
# 19                       15                    15                 15
# 20                       90                    89                 52
# 21                       85                    90                 52
# 22                        7                    11                 15
# 23                       33                    37                 15
# 24                        7                    10                 15
# 25                        7                    10                 15
# 26                       87                    89                 54
# 27                       15                     9                 15
# 28                        8                    14                 15
# 29                       11                     7                 15
#
#     attacking_work_rate  defending_work_rate  outfield
# 0                     3                    1         1
# 1                     5                    3         1
# 2                     5                    1         1
# 3                     5                    3         1
# 4                     5                    5         1
# 5                     3                    3         0
# 6                     5                    1         1
# 7                     3                    3         0
# 8                     3                    3         0
# 9                     5                    5         1
# 10                    3                    5         1
# 11                    3                    3         1
# 12                    3                    3         0
# 13                    5                    5         1
# 14                    5                    5         1
# 15                    3                    3         1
# 16                    5                    3         1
# 17                    5                    3         1
# 18                    3                    3         0
# 19                    5                    3         1
# 20                    3                    3         0
# 21                    3                    3         0
# 22                    5                    3         1
# 23                    5                    3         1
# 24                    3                    3         1
# 25                    3                    3         1
# 26                    3                    3         0
# 27                    5                    3         1
# 28                    5                    5         1
# 29                    5                    5         1
#
# [30 rows x 48 columns]

# %%
# Task 3 - We also need randomize it - it is currently sorted in overall value (descending order)
# https://stackoverflow.com/questions/29576430/shuffle-dataframe-rows
# https://stackoverflow.com/questions/15772009/shuffling-permutating-a-dataframe-in-pandas
test_df = sklearn.utils.shuffle(fifa_df)

# %%
test_df.head(20)
# Out:
#        overall  potential  height_cm  weight_kg  pace  shooting  passing  \
# 11091       64         64        185         71    40        23       43
# 17384       57         63        183         75    74        54       37
# 1476        75         75        183         80    51        58       68
# 9078        66         68        182         76    58        28       41
# 562         79         79        182         75    64        33       59
# 6330        69         74        195         85    63        37       55
# 685         78         78        179         77    39        66       68
# 15034       61         64        187         81    59        27       43
# 451         80         80        179         73    69        69       80
# 13342       63         80        182         81    80        63       52
# 11466       64         64        187         78    60        63       53
# 18689       52         66        181         68    28        18       25
# 10567       65         71        178         73    85        55       60
# 5493        69         69        185         85    34        37       48
# 6538        68         68        175         71    72        60       65
# 14619       61         75        190         84    45        64       47
# 1397        76         80        175         70    76        73       71
# 1732        75         75        175         68    81        73       72
# 11244       64         64        182         69    78        55       59
# 233         82         82        167         66    90        78       77
#
#        dribbling  defending  physic  ...  defending_sliding_tackle  \
# 11091         46         64      77  ...                        63
# 17384         54         18      65  ...                        12
# 1476          59         76      69  ...                        73
# 9078          50         66      72  ...                        66
# 562           58         80      82  ...                        80
# 6330          53         67      76  ...                        62
# 685           68         78      87  ...                        77
# 15034         42         61      67  ...                        58
# 451           83         66      68  ...                        65
# 13342         60         30      64  ...                        22
# 11466         61         61      72  ...                        63
# 18689         27         14      29  ...                        10
# 10567         66         49      67  ...                        52
# 5493          48         68      78  ...                        63
# 6538          64         62      67  ...                        65
# 14619         53         25      65  ...                        12
# 1397          82         35      52  ...                        29
# 1732          75         42      54  ...                        34
# 11244         65         61      65  ...                        60
# 233           79         59      79  ...                        59
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 11091                   7                     6                    7
# 17384                  13                     9                    7
# 1476                    9                    10                    7
# 9078                   11                    11                   13
# 562                     8                    13                   12
# 6330                   12                    15                    9
# 685                     8                     8                    9
# 15034                  10                    11                    9
# 451                     6                    15                    8
# 13342                   6                    13                    6
# 11466                   6                     6                   13
# 18689                  53                    58                   48
# 10567                   6                    14                    5
# 5493                   11                    13                   11
# 6538                   13                    12                    8
# 14619                  10                    14                   10
# 1397                    9                     7                    5
# 1732                   10                    13                   12
# 11244                   8                    11                    8
# 233                    14                    10                   15
#
#        goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed  \
# 11091                        7                     8                 15
# 17384                        8                     8                 15
# 1476                        11                    15                 15
# 9078                         6                     6                 15
# 562                         12                     8                 15
# 6330                        15                    15                 15
# 685                         13                    16                 15
# 15034                       10                     6                 15
# 451                          8                     8                 15
# 13342                       14                    10                 15
# 11466                       12                    11                 15
# 18689                       53                    52                 20
# 10567                       12                    14                 15
# 5493                         6                     6                 15
# 6538                         9                    13                 15
# 14619                        6                     7                 15
# 1397                         6                    14                 15
# 1732                        14                     7                 15
# 11244                       13                    12                 15
# 233                         15                    13                 15
#
#        attacking_work_rate  defending_work_rate  outfield
# 11091                    3                    5         1
# 17384                    5                    3         1
# 1476                     3                    3         1
# 9078                     3                    3         1
# 562                      3                    5         1
# 6330                     5                    3         1
# 685                      3                    3         1
# 15034                    3                    3         1
# 451                      3                    3         1
# 13342                    3                    1         1
# 11466                    3                    3         1
# 18689                    3                    3         0
# 10567                    5                    5         1
# 5493                     3                    5         1
# 6538                     5                    5         1
# 14619                    3                    3         1
# 1397                     3                    1         1
# 1732                     3                    3         1
# 11244                    3                    3         1
# 233                      5                    5         1
#
# [20 rows x 48 columns]

# %%
# Task 4 - We will then save our engineered data. 

if not os.path.isdir('binary_classification_data'):
    os.makedirs('binary_classification_data')
    
test_df.to_csv('binary_classification_data/players.csv', index=False)

# %%
# https://www.sharpsightlabs.com/blog/pandas-iloc/

def split70_20_10(df):
    train = pd.DataFrame()
    valid = pd.DataFrame()
    test = pd.DataFrame()
    
    length = df.shape[0]
    
    cutoff_idx = 70 * length // 100
    train_idx = 10 * length // 100 
    
    temp_train = df.iloc[:cutoff_idx]
    temp_validation = df.iloc[cutoff_idx: cutoff_idx+train_idx]
    temp_test = df.iloc[cutoff_idx+train_idx:]
    
    train = train.append(temp_train)
    valid = valid.append(temp_validation)
    test = test.append(temp_test)
    
    return train, valid, test

# %%
train_outfield_df, valid_outfield_df, test_outfield_df = split70_20_10(test_df)
# Out:
# /var/folders/z6/hgtgdd9502lbqgzmmg88__ym0000gn/T/ipykernel_38683/2521575833.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(temp_train)
# /var/folders/z6/hgtgdd9502lbqgzmmg88__ym0000gn/T/ipykernel_38683/2521575833.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid = valid.append(temp_validation)
# /var/folders/z6/hgtgdd9502lbqgzmmg88__ym0000gn/T/ipykernel_38683/2521575833.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test = test.append(temp_test)

# %%
# # Check that the train/test sizes are about 80/20

print('Train length: ', len(train_outfield_df))
print('Test length: ', len(valid_outfield_df))
print('Test length: ', len(test_outfield_df))
print()
print('Decimal % test data of total data: ', len(test_outfield_df)
      /(len(train_outfield_df)+len(valid_outfield_df)+len(test_outfield_df)))
# Out:
# Train length:  13467
# Test length:  1923
# Test length:  3849
#
# Decimal % test data of total data:  0.2000623733042258

# %%
directory = 'binary_classification_data'

if not os.path.isdir(directory):
    os.makedirs(directory)
                
train_outfield_df.to_csv(directory + '/training_players.csv', index=False)
valid_outfield_df.to_csv(directory + '/valid_players.csv', index=False)
test_outfield_df.to_csv(directory + '/test_players.csv', index=False)

# %%
# Optional: Create a baseline**

import turitrove as trove
import turicreate as tc
train_path = 'prepared_outfield_player_data/training_outfield.csv'
test_path = 'prepared_outfield_player_data/test_outfield.csv'

train_battery_df = pd.read_csv(train_path)
test_battery_df = pd.read_csv(test_path)

train_battery_sf = tc.SFrame(train_battery_df)
test_battery_sf = tc.SFrame(test_battery_df)

target = 'overall'
train_battery_sf[target].show()
# Out:
# !! Could not derive your terminal width !!
# Materializing SArray
# <html>                 <body>                     <iframe style="border:0;margin:0" width="920" height="770" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"description\": \"A simple bar chart with embedded data.\", \"autosize\": {\"type\": \"fit\", \"resize\": false, \"contains\": \"padding\"}, \"width\": 720, \"height\": 550, \"padding\": 8, \"title\": \"Distribution of Values [integer]\", \"style\": \"cell\", \"signals\": [{\"name\": \"bins\", \"update\": \"data(\\\"bins_data\\\")[0]\"}, {\"name\": \"binCount\", \"update\": \"(bins.stop - bins.start) / bins.step\"}, {\"name\": \"nullGap\", \"update\": \"data(\\\"nulls\\\").length ? 10 : 0\"}, {\"name\": \"barStep\", \"update\": \"(width - nullGap) / (1 + binCount)\"}], \"data\": [{\"name\": \"source_2\", \"values\": [{\"left\": 41, \"right\": 44, \"count\": 0}, {\"left\": 44, \"right\": 47, \"count\": 0}, {\"left\": 47, \"right\": 50, \"count\": 78}, {\"left\": 50, \"right\": 53, \"count\": 253}, {\"left\": 53, \"right\": 56, \"count\": 522}, {\"left\": 56, \"right\": 59, \"count\": 768}, {\"left\": 59, \"right\": 62, \"count\": 1298}, {\"left\": 62, \"right\": 65, \"count\": 2040}, {\"left\": 65, \"right\": 68, \"count\": 2269}, {\"left\": 68, \"right\": 71, \"count\": 1829}, {\"left\": 71, \"right\": 74, \"count\": 1386}, {\"left\": 74, \"right\": 77, \"count\": 815}, {\"left\": 77, \"right\": 80, \"count\": 405}, {\"left\": 80, \"right\": 83, \"count\": 196}, {\"left\": 83, \"right\": 86, \"count\": 76}, {\"left\": 86, \"right\": 89, \"count\": 29}, {\"left\": 89, \"right\": 92, \"count\": 8}, {\"left\": 92, \"right\": 95, \"count\": 2}, {\"left\": 95, \"right\": 98, \"count\": 0}, {\"left\": 98, \"right\": 101, \"count\": 0}, {\"start\": 41, \"stop\": 101, \"step\": 3}]}, {\"name\": \"counts\", \"source\": \"source_2\", \"transform\": [{\"type\": \"filter\", \"expr\": \"datum[\\\"missing\\\"] !== true &amp;&amp; datum[\\\"count\\\"] != null\"}]}, {\"name\": \"nulls\", \"source\": \"source_2\", \"transform\": [{\"expr\": \"datum[\\\"missing\\\"] === true &amp;&amp; datum[\\\"count\\\"] != null\", \"type\": \"filter\"}]}, {\"name\": \"bins_data\", \"source\": \"source_2\", \"transform\": [{\"expr\": \"datum[\\\"start\\\"] != null &amp;&amp ...

# %%
select_input_features = ['potential',
'age',
'height_cm',
'weight_kg',
'league_level',
'weak_foot',
'skill_moves',
'international_reputation',
'pace',
'shooting',
'passing',
'dribbling',
'defending',
'physic',
'attacking_crossing',
'attacking_finishing',
'attacking_heading_accuracy',
'attacking_short_passing',
'attacking_volleys',
'skill_dribbling',
'skill_curve',
'skill_fk_accuracy',
'skill_long_passing',
'skill_ball_control',
'movement_acceleration',
'movement_sprint_speed',
'movement_agility',
'movement_reactions',
'movement_balance',
'power_shot_power',
'power_jumping',
'power_stamina',
'power_strength',
'power_long_shots',
'mentality_aggression',
'mentality_interceptions',
'mentality_positioning',
'mentality_vision',
'mentality_penalties',
'mentality_composure',
'defending_marking_awareness',
'defending_standing_tackle',
'defending_sliding_tackle',
'goalkeeping_diving',
'goalkeeping_handling',
'goalkeeping_kicking',
'goalkeeping_positioning',
'goalkeeping_reflexes',
'attacking_work_rate',
'defending_work_rate']

# %%
# train/create a baseline linear regression
battery_model = tc.linear_regression.create(train_battery_sf, 
                                               target = 'overall',
                                               features=select_input_features) # sf, target, features
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 11375
# Number of features          : 50
# Number of unpacked features : 50
# Number of coefficients    : 51
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | 1         | 2        | 1.018152     | 8.733289           | 6.972363             | 1.669544                        | 1.743896                          |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
# eval on test data 


battery_model.evaluate(test_battery_sf)
# Out:
# {'max_error': 7.254479198396396, 'rmse': 1.7214720242760098}

# %%
battery_model.coefficients
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 51
#
# Data:
# +--------------------------+-------+-----------------------+
# |           name           | index |         value         |
# +--------------------------+-------+-----------------------+
# |       (intercept)        |  None |   -8.65602222104995   |
# |        potential         |  None |   0.4066535622017121  |
# |           age            |  None |  0.43242887082512704  |
# |        height_cm         |  None | -0.015891844100721263 |
# |        weight_kg         |  None |  0.02360074587965036  |
# |       league_level       |  None |  -0.13885226688336438 |
# |        weak_foot         |  None |  -0.07637968460485785 |
# |       skill_moves        |  None |   0.3975367978299376  |
# | international_reputation |  None |   0.2809782781778606  |
# |           pace           |  None | -0.024432639079692158 |
# +--------------------------+-------+-----------------------+
# +-----------------------+
# |         stderr        |
# +-----------------------+
# |   0.8932907697760151  |
# |  0.005120324384127446 |
# | 0.0065579005492057505 |
# |  0.004648288581495391 |
# |  0.004152428615998978 |
# |  0.021897928273667346 |
# |  0.025961072561824804 |
# |  0.03584373150294193  |
# |  0.04950110579875884  |
# |  0.05393785607320557  |
# +-----------------------+
# [51 rows x 4 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
test_df.shape
# Out:
# (17107, 51)
